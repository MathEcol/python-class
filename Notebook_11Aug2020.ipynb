# %%
""" 
This is a comment
This is a comment
"""
2+3
# Out:
# 5

# %%
2+3
3*6
5-2.7
# Out:
# 2.3

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
2+3
3*5
5-2.27
# Out:
# 5
# 15
# 2.73

# %%
# %timeit range(100)
# Out:
# 196 ns ± 25.3 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
import numpy
x = numpy.matrix ([[1 ,2] ,[2 ,4]])
eig = numpy.linalg.eigvals(x)
print(eig)
# Out:
# [0. 5.]

# %%
import numpy

# %%
# %%timeit x = numpy.matrix ([[1 ,2] ,[2 ,4]])
eig = numpy.linalg.eigvals(x)
print(eig)
# Out:
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# ...

# %%
# %pwd
# Out:
# 'D:\\JupyterNotebooks'

# %%
# %ls
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is F4C2-0FD0
#
#  Directory of D:\JupyterNotebooks
#
# 11-08-2020  11:40    <DIR>          .
# 11-08-2020  11:40    <DIR>          ..
# 11-08-2020  11:33    <DIR>          .ipynb_checkpoints
# 08-08-2020  16:10    <DIR>          .virtual_documents
# 04-08-2020  13:00           398,808 FirstPythonNotebook.ipynb
# 05-08-2020  14:22             1,451 InteractiveShellEx.ipynb
# 11-08-2020  11:40           163,792 Notebook_11Aug.ipynb
# 08-08-2020  09:11         5,905,315 Notebook_Aug06.ipynb
# 08-08-2020  11:20           140,760 Notebook_Aug08.ipynb
# 08-08-2020  16:12               581 Untitled.ipynb
# 08-08-2020  11:28             2,911 Untitled1.ipynb
#                7 File(s)      6,613,618 bytes
#                4 Dir(s)  25,823,809,536 bytes free

# %%
# %dir
# Out:
# UsageError: Line magic function `%dir` not found.

# %%
# %cd D:\\
# Out:
# D:\

# %%
# %pwd
# Out:
# 'D:\\'

# %%
pwd
# Out:
# 'D:\\'

# %%
# %history
# Out:
# 2+3
# 3*2
# 2+3
# 3*6
# 5-2.7
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
# 2+3
# 3*5
# 5-2.27
# %timeit range(100)
# %% timeit x = numpy.matrix ([[1 ,2] ,[2 ,4]])
# eig = numpy.linalg.eigvals(x)
# print(eig)
# %%timeit x = numpy.matrix ([[1 ,2] ,[2 ,4]])
# eig = numpy.linalg.eigvals(x)
# print(eig)
# import numpy
# %%timeit x = numpy.matrix ([[1 ,2] ,[2 ,4]])
# eig = numpy.linalg.eigvals(x)
# print(eig)
# import numpy
# %%timeit x = numpy.matrix ([[1 ,2] ,[2 ,4]])
# %%timeit x = numpy.matrix ([[1 ,2] ,[2 ,4]])
# eig = numpy.linalg.eigvals(x)
# print(eig)
# %pwd
# %ls
# %dir
# %cd D:\\
# pwd
# %pwd
# pwd
# %history

# %%
pwd
# Out:
# 'D:\\'

# %%
mkdir Testing

# %%
cd D:\\Testing
# Out:
# D:\Testing

# %%
pwd
# Out:
# 'D:\\Testing'

# %%
ls
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is F4C2-0FD0
#
#  Directory of D:\Testing
#
# 11-08-2020  11:42    <DIR>          .
# 11-08-2020  11:42    <DIR>          ..
#                0 File(s)              0 bytes
#                2 Dir(s)  25,823,805,440 bytes free

# %%
cd D:\\JupyterNotebooks
# Out:
# D:\JupyterNotebooks

# %%
pwd
# Out:
# 'D:\\JupyterNotebooks'

# %%
ls
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is F4C2-0FD0
#
#  Directory of D:\JupyterNotebooks
#
# 11-08-2020  11:42    <DIR>          .
# 11-08-2020  11:42    <DIR>          ..
# 11-08-2020  11:33    <DIR>          .ipynb_checkpoints
# 08-08-2020  16:10    <DIR>          .virtual_documents
# 04-08-2020  13:00           398,808 FirstPythonNotebook.ipynb
# 05-08-2020  14:22             1,451 InteractiveShellEx.ipynb
# 11-08-2020  11:42           167,641 Notebook_11Aug.ipynb
# 08-08-2020  09:11         5,905,315 Notebook_Aug06.ipynb
# 08-08-2020  11:20           140,760 Notebook_Aug08.ipynb
# 08-08-2020  16:12               581 Untitled.ipynb
# 08-08-2020  11:28             2,911 Untitled1.ipynb
#                7 File(s)      6,617,467 bytes
#                4 Dir(s)  25,823,805,440 bytes free

# %%
# %timeit sum(range(100))
# Out:
# 2.18 µs ± 462 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# 432 ms ± 49.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %magic

# %%
s = 'name'
print(s)
# Out:
# name

# %%
s = 'My name is Prasad!'

# %%
print(s)
# Out:
# My name is Prasad!

# %%
s = 'My name is Prasad!,
I am AP'
# Out:
#   File "<ipython-input-34-80f91a734426>", line 1
#     s = 'My name is Prasad!,
#                             ^
# SyntaxError: EOL while scanning string literal

# %%
s = '''My name is Prasad!
I am from AP'''
print(s)
# Out:
# My name is Prasad!
# I am from AP

# %%
s = """My name is,
Prasad!
I am from AP"""
print(s)
# Out:
# My name is,
# Prasad!
# I am from AP

# %%
"""
This is first comment line
This is econd comment line
"""
print('Hello...')
# Out:
# '\nThis is first comment line\nThis is econd comment line\n'
# Hello...

# %%
S = 'Hello.... World!'

# %%
S[0]
# Out:
# 'H'

# %%
S[1]
# Out:
# 'e'

# %%
S[10]
# Out:
# 'W'

# %%
len(S)

# %%
S = 'Hello.... World!'

# %%
len(S)
# Out:
# 16

# %%
S[0]
# Out:
# 'H'

# %%
S[1:4] #S[start:end] then the string will start from start index and ends with end-1
# Out:
# 'ell'

# %%
S[2:8]
# Out:
# 'llo...'

# %%
l = len(S)

# %%
print(l)
# Out:
# 16

# %%
S[10:l-1]
# Out:
# 'World'

# %%
S[-5:-2]
# Out:
# 'orl'

# %%
S[-5:-1]
# Out:
# 'orld'

# %%
S1 = 'Hello'
S2 = 'World!'
print(S1+S2)
# Out:
# HelloWorld!

# %%
print(S1 + " " + S2)
# Out:
# Hello World!

# %%
S1 = "Hello"
no = 10
print(S1+str(no))
# Out:
# Hello10

# %%
S1 = "Tom"
Age = 30
Place = "Space"
txt = S1 + " is of age " + str(Age) + " and he is from " + Place
print(txt)
# Out:
# Tom is of age 30 and he is from Space

# %%
txt = "{} is of age {} and he is from {}"

# %%
print(txt)
# Out:
# {} is of age {} and he is from {}

# %%
print(txt.format(S1,Age,Place))
# Out:
# Tom is of age 30 and he is from Space

# %%
print(txt.format(Age,S1,Place))
# Out:
# 30 is of age Tom and he is from Space

# %%
txt = "{1} is of age {0} and he is from {3}"
print(txt.format(Age,S1,Place,45.3234))
# Out:
# Tom is of age 30 and he is from 45.3234

# %%
txt = "When {} divided by {} the result is {}"

# %%
print(txt.format(12,3,12/3))
# Out:
# When 12 divided by 3 the result is 4.0

# %%
txt = 'Hello World!'

# %%
txt.replace('H','J')
# Out:
# 'Jello World!'

# %%
txt.replace('o','#')
# Out:
# 'Hell# W#rld!'

# %%
print(txt)
# Out:
# Hello World!

# %%
txt.replace('Hello','Hai')
# Out:
# 'Hai World!'

# %%
txt.replace('lo','loooooo')
# Out:
# 'Helloooooo World!'

# %%
txt
# Out:
# 'Hello World!'

# %%
txt.split(" ")
# Out:
# ['Hello', 'World!']

# %%
txt.split("o")
# Out:
# ['Hell', ' W', 'rld!']

# %%
txt = 'Hello, World!'

# %%
txt.split(",")
# Out:
# ['Hello', ' World!']

# %%
txt
# Out:
# 'Hello, World!'

# %%
x = "lo" in txt

# %%
print(x)
# Out:
# True

# %%
x = 'Lo' in txt

# %%
print(x)
# Out:
# False

# %%
x = 'lo' not in txt

# %%
print(x)
# Out:
# False

# %%
txt = "    Hello     World!    "

# %%
print(txt)
# Out:
#     Hello     World!

# %%
print(txt.strip())
# Out:
# Hello     World!

# %%
print(txt)
# Out:
#     Hello     World!

# %%
print(txt.lstrip())
# Out:
# Hello     World!

# %%
print(txt.rstrip())
# Out:
#     Hello     World!

# %%
txt = 'hello World!'

# %%
txt.lower()
# Out:
# 'hello world!'

# %%
txt.upper()
# Out:
# 'HELLO WORLD!'

# %%
txt.lower() == txt.upper()
# Out:
# False

# %%
txt == txt.lower()
# Out:
# False

# %%
txt.capitalize()
# Out:
# 'Hello world!'

# %%
txt = 'this Is a Testing Line'

# %%
txt.capitalize()
# Out:
# 'This is a testing line'

# %%
txt = txt.capitalize()

# %%
print(txt)
# Out:
# This is a testing line

# %%
txt.title()
# Out:
# 'This Is A Testing Line'

# %%
txt.swapcase()
# Out:
# 'tHIS IS A TESTING LINE'

# %%
txt.islower()
# Out:
# False

# %%
txt.isupper()
# Out:
# False

# %%
txt.istitle()
# Out:
# False

# %%
txt = txt.title()

# %%
txt.istitle()
# Out:
# True

# %%
txt
# Out:
# 'This Is A Testing Line'

# %%
txt.count("i")
# Out:
# 3

# %%
txt.count("in")
# Out:
# 2

# %%
txt.find("A")
# Out:
# 8

# %%
txt.find("is")
# Out:
# 2

# %%
txt.find("in")
# Out:
# 14

# %%
txt.isalnum()
# Out:
# False

# %%
txt = 'This is 10'

# %%
txt.isalnum()
# Out:
# False

# %%
txt.isalpha()
# Out:
# False

# %%
txt.isdigit()
# Out:
# False

# %%
txt
# Out:
# 'This is 10'

# %%
txt = 'This is ten'

# %%
txt.isalpha()
# Out:
# False

# %%
txt.isdigit()
# Out:
# False

# %%
txt = '10'

# %%
txt.isdigit()
# Out:
# True

# %%
txt = 'A'

# %%
txt.isalpha()
# Out:
# True

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
ord('1')
# Out:
# 49

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
ord('#')
# Out:
# 35

# %%
chr(65)
# Out:
# 'A'

# %%
chr(35)
# Out:
# '#'

# %%
chr(100)
# Out:
# 'd'

# %%
chr(1256)
# Out:
# 'Ө'

# %%
ord('Ө')
# Out:
# 1256

# %%
chr(229)
# Out:
# 'å'

# %%
print('This is name starting with ', chr(229))
# Out:
# This is name starting with  å

# %%
print('The ASCII value of \'A\' is: ', ord('A'))
# Out:
# The ASCII value of 'A' is:  65

# %%
print("The ASCII value of \"A\" is: ", ord('A'))
# Out:
# The ASCII value of "A" is:  65

# %%
print('The ASCII Value of A is: \n',ord('A'))
# Out:
# The ASCII Value of A is:
#  65

# %%
print('The ASCII Value of A is: \t',ord('A'))
# Out:
# The ASCII Value of A is: 	 65

# %%
\n
\t
\'
\"
